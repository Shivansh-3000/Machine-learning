# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame(np.arange(0,20).reshape(5,4),index = ['Row1','Row2','Row3','Row4','Row5'],columns = ['c1','c2','c3','c4'])

# %%
df1
# Out:
#       c1  c2  c3  c4
# Row1   0   1   2   3
# Row2   4   5   6   7
# Row3   8   9  10  11
# Row4  12  13  14  15
# Row5  16  17  18  19

# %%
df1.to_csv('name.csv')

# %%
df1.loc['Row1']
# Out:
# c1    0
# c2    1
# c3    2
# c4    3
# Name: Row1, dtype: int32

# %%
df1['c1']
# Out:
# Row1     0
# Row2     4
# Row3     8
# Row4    12
# Row5    16
# Name: c1, dtype: int32

# %%
df1['c1'].values
# Out:
# array([ 0,  4,  8, 12, 16])

# %%
df1['c1'].value_counts()
# Out:
# 0     1
# 8     1
# 4     1
# 16    1
# 12    1
# Name: c1, dtype: int64

# %%
df1.loc['Row1'].unique()
# Out:
# array([0, 1, 2, 3])

# %%
df1.loc['Row1'].sum()
# Out:
# 6

# %%
df1.loc['Row1'].value_counts()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# Name: Row1, dtype: int64

# %%
df = pd.read_csv('Anime.csv')

# %%
df
# Out:
#         Rank                                               Name  \
# 0          1  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1          2                     Fruits Basket the Final Season
# 2          3                                    Mo Dao Zu Shi 3
# 3          4                   Fullmetal Alchemist: Brotherhood
# 4          5                Attack on Titan 3rd Season: Part II
# ...      ...                                                ...
# 18490  18491  Qin Shi Mingyue: Canghai Hengliu Xiaomeng Spec...
# 18491  18492                      Yi Tang Juchang: Sanguo Yanyi
# 18492  18493          Fenghuang Ji Xiang Yu Qingming Shanghe Tu
# 18493  18494                      Chengshi Jiyi Wo Men de Jieri
# 18494  18495  Heisei Inu Monogatari Bow: Genshi Inu Monogata...
#
#                                          Japanese_name   Type  Episodes  \
# 0                        Kimetsu no Yaiba: Yuukaku-hen  TV          NaN
# ...

# %%
df.describe()
# Out:
#               Rank     Episodes        Rating  Release_year     End_year
# count  18495.00000  9501.000000  15364.000000  18112.000000  2854.000000
# mean    9248.00000    20.920850      3.355133   2006.520318  2004.256132
# std     5339.19095    37.990858      0.400624     15.189537    13.257484
# min        1.00000     1.000000      0.960000   1907.000000  1962.000000
# 25%     4624.50000     2.000000      3.130000   2001.000000  1996.000000
# 50%     9248.00000    12.000000      3.360000   2012.000000  2007.000000
# 75%    13871.50000    26.000000      3.590000   2017.000000  2015.000000
# max    18495.00000   800.000000      4.600000   2023.000000  2022.000000

# %%
df.loc[1]
# Out:
# Rank                                                               2
# Name                                  Fruits Basket the Final Season
# Japanese_name                                Fruits Basket the Final
# Type                                                           TV
# Episodes                                                        13.0
# Studio                                             TMS Entertainment
# Release_season                                                Spring
# Tags               Drama, Fantasy, Romance, Shoujo, Animal Transf...
# Rating                                                           4.6
# Release_year                                                  2021.0
# End_year                                                         NaN
# Description                        'The final arc of Fruits Basket.'
# Content_Warning    Emotional Abuse,, Mature Themes,, Physical Abu...
# Related_Mange                   Fruits Basket, Fruits Basket Another
# ...

# %%
df['Tags']
# Out:
# 0        Action, Adventure, Fantasy, Shounen, Demons, H...
# 1        Drama, Fantasy, Romance, Shoujo, Animal Transf...
# 2        Fantasy, Ancient China, Chinese Animation, Cul...
# 3        Action, Adventure, Drama, Fantasy, Mystery, Sh...
# 4        Action, Fantasy, Horror, Shounen, Dark Fantasy...
#                                ...
# 18490    Action, Ancient China, Chinese Animation, Hist...
# 18491                                    Chinese Animation
# 18492    Chinese Animation, Family Friendly, Short Epis...
# 18493    Chinese Animation, Family Friendly, Short Epis...
# 18494                          Comedy, Slice of Life, Dogs
# Name: Tags, Length: 18495, dtype: object

# %%
df.iloc[0:3,:]
# Out:
#    Rank                                               Name  \
# 0     1  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1     2                     Fruits Basket the Final Season
# 2     3                                    Mo Dao Zu Shi 3
#
#                     Japanese_name   Type  Episodes             Studio  \
# 0   Kimetsu no Yaiba: Yuukaku-hen  TV          NaN           ufotable
# 1         Fruits Basket the Final  TV         13.0  TMS Entertainment
# 2      The Founder of Diabolism 3  Web        12.0   B.C MAY PICTURES
#
#   Release_season                                               Tags  Rating  \
# 0          Fall   Action, Adventure, Fantasy, Shounen, Demons, H...    4.60
# 1         Spring  Drama, Fantasy, Romance, Shoujo, Animal Transf...    4.60
# 2            NaN  Fantasy, Ancient China, Chinese Animation, Cul...    4.58
#
#    Release_year  End_year                                        Description  \
# ...

# %%
df.iloc[0:3,0:1]
# Out:
#    Rank
# 0     1
# 1     2
# 2     3

# %%
df['Rating'].sum()
# Out:
# 51548.259999999995

# %%
df1 = pd.read_csv('Anime.csv',usecols = ['Name','Type','Episodes'])

# %%
df1
# Out:
#                                                     Name   Type  Episodes
# 0      Demon Slayer: Kimetsu no Yaiba - Entertainment...  TV          NaN
# 1                         Fruits Basket the Final Season  TV         13.0
# 2                                        Mo Dao Zu Shi 3  Web        12.0
# 3                       Fullmetal Alchemist: Brotherhood  TV         64.0
# 4                    Attack on Titan 3rd Season: Part II  TV         10.0
# ...                                                  ...    ...       ...
# 18490  Qin Shi Mingyue: Canghai Hengliu Xiaomeng Spec...  Web         2.0
# 18491                      Yi Tang Juchang: Sanguo Yanyi  TV        108.0
# 18492          Fenghuang Ji Xiang Yu Qingming Shanghe Tu  TV         13.0
# 18493                      Chengshi Jiyi Wo Men de Jieri  TV          NaN
# 18494  Heisei Inu Monogatari Bow: Genshi Inu Monogata...  Movie       NaN
#
# [18495 rows x 3 columns]

# %%
number = int(input("Enter episodes"))
jo = input("Enter tags")
# Out:
# Enter episodesnrgef
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-86d0f45f6180> in <module>
# ----> 1 number = int(input("Enter episodes"))
#       2 jo = input("Enter tags")
#
# ValueError: invalid literal for int() with base 10: 'nrgef'

# %%
df[df['Episodes']==64]
# Out:
#         Rank                               Name  \
# 3          4   Fullmetal Alchemist: Brotherhood
# 888      889                    Wushang Shen Di
# 1888    1889                        Shaman King
# 3559    3560                    Zhan Long Si Qu
# 4829    4830  Puchimas! Petit [email protected]
# 5455    5456             Future Card Buddyfight
# 6306    6307                      Chie the Brat
# 7038    7039                         StarZinger
# 8509    8510                     Dragon Ball GT
# 10832  10833           Rokushin Gattai God Mars
# 15708  15709           Chao Neng Xiao Yingxiong
# 17121  17122        Hong Mao Lan Tu: Le Fantian
#
#                                          Japanese_name   Type  Episodes  \
# 3       Hagane no Renkinjutsushi: Full Metal Alchemist  TV         64.0
# 888                                                NaN  Web        64.0
# 1888                                               NaN  TV         64.0
# ...

# %%
df[df['Type']=='TV']
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Japanese_name, Type, Episodes, Studio, Release_season, Tags, Rating, Release_year, End_year, Description, Content_Warning, Related_Mange, Related_anime, Voice_actors, staff]
# Index: []

# %%
df1[df1['Type']=='Web']
# Out:
# Empty DataFrame
# Columns: [Name, Type, Episodes]
# Index: []

# %%
df1['Type']=='Web'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18490    False
# 18491    False
# 18492    False
# 18493    False
# 18494    False
# Name: Type, Length: 18495, dtype: bool

# %%
df1 = pd.read_csv('Anime.csv',usecols = ['Name','Type','Episodes'])

# %%
df = df1.iloc[:,1:2]=='Web   '

# %%
df2 = df1[df1['Episodes']<100]

# %%
df2
# Out:
#                                                     Name   Type  Episodes
# 1                         Fruits Basket the Final Season  TV         13.0
# 2                                        Mo Dao Zu Shi 3  Web        12.0
# 3                       Fullmetal Alchemist: Brotherhood  TV         64.0
# 4                    Attack on Titan 3rd Season: Part II  TV         10.0
# 5                                         Jujutsu Kaisen  TV         24.0
# ...                                                  ...    ...       ...
# 18476                 Love is in small things 2nd Season  Web        32.0
# 18477                               Living with Garfield  Web        12.0
# 18485                Zhandou Ba Geji! Shanyao de Richang  Web        86.0
# 18490  Qin Shi Mingyue: Canghai Hengliu Xiaomeng Spec...  Web         2.0
# 18492          Fenghuang Ji Xiang Yu Qingming Shanghe Tu  TV         13.0
#
# [9245 rows x 3 columns]

# %%
df3 = df1[df1['Type']=='Web  ']

# %%
df3
# Out:
#                                                     Name   Type  Episodes
# 2                                        Mo Dao Zu Shi 3  Web        12.0
# 17                    Heaven Official's Blessing Special  Web         1.0
# 21                                       Mo Dao Zu Shi 2  Web         8.0
# 23                                            Link Click  Web        11.0
# 30                            Heaven Official's Blessing  Web        11.0
# ...                                                  ...    ...       ...
# 18479                                     Baise Shandian  Web         NaN
# 18480  Bridgestone: Chase Your Dream - The Journey of...  Web         NaN
# 18485                Zhandou Ba Geji! Shanyao de Richang  Web        86.0
# 18487                                        Make My Day  Web         NaN
# 18490  Qin Shi Mingyue: Canghai Hengliu Xiaomeng Spec...  Web         2.0
#
# [2488 rows x 3 columns]

# %%
df4
# Out:
#                                                     Name   Type  Episodes
# 128                                            One Piece  TV        100.0
# 1197                                   Aggretsuko (2016)  TV        100.0
# 2795                                            Gudetama  TV        100.0
# 6456                                           Coji-Coji  TV        100.0
# 7162                           Manga Doushite Monogatari  TV        100.0
# 7959                                            Kuruneko  TV        100.0
# 8080                            GeGeGe no Kitarou (2007)  TV        100.0
# 8573                    Eigo de Asobo: Tanken Goblin Tou  TV        100.0
# 8975                               Sekai Monoshiri Ryoko  TV        100.0
# 9348                                          Goman-hiki  TV        100.0
# 10886                           Doubutsu Mura Monogatari  TV        100.0
# 12227                           Kirby: Right Back At Ya!  TV        100.0
# ...

# %%
df5 = pd.read_csv('Anime.csv',usecols = ['Name','Type','Episodes','Tags'])

# %%
df2 = df5['Tags']

# %%
k = df2[0].split()

# %%
df2
# Out:
# 0        Action, Adventure, Fantasy, Shounen, Demons, H...
# 1        Drama, Fantasy, Romance, Shoujo, Animal Transf...
# 2        Fantasy, Ancient China, Chinese Animation, Cul...
# 3        Action, Adventure, Drama, Fantasy, Mystery, Sh...
# 4        Action, Fantasy, Horror, Shounen, Dark Fantasy...
#                                ...
# 18490    Action, Ancient China, Chinese Animation, Hist...
# 18491                                    Chinese Animation
# 18492    Chinese Animation, Family Friendly, Short Epis...
# 18493    Chinese Animation, Family Friendly, Short Epis...
# 18494                          Comedy, Slice of Life, Dogs
# Name: Tags, Length: 18495, dtype: object

# %%
df2[0]
# Out:
# 'Action, Adventure, Fantasy, Shounen, Demons, Historical, Martial Arts, Orphans, Siblings, Swordplay, Based on a Manga, Explicit Violence'

# %%
df2
# Out:
# 0        Action, Adventure, Fantasy, Shounen, Demons, H...
# 1        Drama, Fantasy, Romance, Shoujo, Animal Transf...
# 2        Fantasy, Ancient China, Chinese Animation, Cul...
# 3        Action, Adventure, Drama, Fantasy, Mystery, Sh...
# 4        Action, Fantasy, Horror, Shounen, Dark Fantasy...
#                                ...
# 18490    Action, Ancient China, Chinese Animation, Hist...
# 18491                                    Chinese Animation
# 18492    Chinese Animation, Family Friendly, Short Epis...
# 18493    Chinese Animation, Family Friendly, Short Epis...
# 18494                          Comedy, Slice of Life, Dogs
# Name: Tags, Length: 18495, dtype: object

# %%
df4
# Out:
#                                                     Name   Type  Episodes
# 128                                            One Piece  TV        100.0
# 1197                                   Aggretsuko (2016)  TV        100.0
# 2795                                            Gudetama  TV        100.0
# 6456                                           Coji-Coji  TV        100.0
# 7162                           Manga Doushite Monogatari  TV        100.0
# 7959                                            Kuruneko  TV        100.0
# 8080                            GeGeGe no Kitarou (2007)  TV        100.0
# 8573                    Eigo de Asobo: Tanken Goblin Tou  TV        100.0
# 8975                               Sekai Monoshiri Ryoko  TV        100.0
# 9348                                          Goman-hiki  TV        100.0
# 10886                           Doubutsu Mura Monogatari  TV        100.0
# 12227                           Kirby: Right Back At Ya!  TV        100.0
# ...

# %%
df5
# Out:
#                                                     Name   Type  Episodes  \
# 0      Demon Slayer: Kimetsu no Yaiba - Entertainment...  TV          NaN
# 1                         Fruits Basket the Final Season  TV         13.0
# 2                                        Mo Dao Zu Shi 3  Web        12.0
# 3                       Fullmetal Alchemist: Brotherhood  TV         64.0
# 4                    Attack on Titan 3rd Season: Part II  TV         10.0
# ...                                                  ...    ...       ...
# 18490  Qin Shi Mingyue: Canghai Hengliu Xiaomeng Spec...  Web         2.0
# 18491                      Yi Tang Juchang: Sanguo Yanyi  TV        108.0
# 18492          Fenghuang Ji Xiang Yu Qingming Shanghe Tu  TV         13.0
# 18493                      Chengshi Jiyi Wo Men de Jieri  TV          NaN
# 18494  Heisei Inu Monogatari Bow: Genshi Inu Monogata...  Movie       NaN
#
#                                                     Tags
# ...

# %%
df2 = df5['Tags']

# %%
df5
# Out:
#                                                     Name   Type  Episodes  \
# 0      Demon Slayer: Kimetsu no Yaiba - Entertainment...  TV          NaN
# 1                         Fruits Basket the Final Season  TV         13.0
# 2                                        Mo Dao Zu Shi 3  Web        12.0
# 3                       Fullmetal Alchemist: Brotherhood  TV         64.0
# 4                    Attack on Titan 3rd Season: Part II  TV         10.0
# ...                                                  ...    ...       ...
# 18490  Qin Shi Mingyue: Canghai Hengliu Xiaomeng Spec...  Web         2.0
# 18491                      Yi Tang Juchang: Sanguo Yanyi  TV        108.0
# 18492          Fenghuang Ji Xiang Yu Qingming Shanghe Tu  TV         13.0
# 18493                      Chengshi Jiyi Wo Men de Jieri  TV          NaN
# 18494  Heisei Inu Monogatari Bow: Genshi Inu Monogata...  Movie       NaN
#
#                                                     Tags
# ...

# %%
inp = input("Enter genre")
inp1 = int(input("Enter minimum number of episodes"))
df2 = df5[df5['Episodes']<=inp1]
df2[df2['Tags'].astype(str).str.contains(inp)]
# Out:
# Enter genreComedy
# Enter minimum number of episodes100
#                                         Name   Type  Episodes  \
# 12            Demon Slayer: Kimetsu no Yaiba  TV         26.0
# 24                         Mob Psycho 100 II  TV         13.0
# 26                  Fruits Basket 2nd Season  TV         25.0
# 30                Heaven Official's Blessing  Web        11.0
# 33     Gintama.: Shirogane no Tamashii-hen 2  TV         14.0
# ...                                      ...    ...       ...
# 18405                      Wo Shi Bu Bai Chi  Web        38.0
# 18438     Hei Hei Yu Baibai: Qi Shan Xuexiao  TV         30.0
# 18458                         Da Jili Chedui  TV         89.0
# 18467                     Qi Qi Miao Le Xing  TV         12.0
# 18485    Zhandou Ba Geji! Shanyao de Richang  Web        86.0
#
#                                                     Tags
# 12     Action, Adventure, Comedy, Drama, Fantasy, Sho...
# ...
