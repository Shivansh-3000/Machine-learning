# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.arange(0,4*np.pi,0.1)
y = np.sin(x)+2

# %%
plt.plot(x,y)

# %%
x = np.arange(1,20)
y = 4*x*x + 3*x -5
plt.plot(x,y)

# %%
x = [2,8,10]
y = [11,13,20]
x1= [3,7,12]
y1= [20,23,26]
plt.bar(x,y,color = 'g')
plt.bar(x1,y1,color = 'b')
# Out:
# <BarContainer object of 3 artists>

# %%
a = np.array([1,2,3,11,12,13,67,68,56,90,92,94])
plt.hist(a,bins=10)
# Out:
# (array([3., 3., 0., 0., 0., 1., 0., 2., 0., 3.]),
#  array([ 1. , 10.3, 19.6, 28.9, 38.2, 47.5, 56.8, 66.1, 75.4, 84.7, 94. ]),
#  <BarContainer object of 10 artists>)

# %%
data = [np.random.normal(0,1,100)]
plt.boxplot(data,vert = True,patch_artist = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x295ffa31160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x295ffa31f70>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x295ffa31580>],
#  'medians': [<matplotlib.lines.Line2D at 0x295ffa3a670>],
#  'fliers': [<matplotlib.lines.Line2D at 0x295ffa3a3a0>],
#  'means': []}

# %%
plt.hist(data)
# Out:
# (array([ 9.,  7., 22., 15., 16., 14., 12.,  3.,  1.,  1.]),
#  array([-1.61510242, -1.17837642, -0.74165041, -0.30492441,  0.13180159,
#          0.5685276 ,  1.0052536 ,  1.4419796 ,  1.8787056 ,  2.31543161,
#          2.75215761]),
#  <BarContainer object of 10 artists>)

# %%
data = [np.random.normal(100,std,1000)for std in range(1,10)]
plt.plot(data)
plt.show()
plt.boxplot(data,vert = True,patch_artist = True)
plt.hist(data)
# Out:
# (array([[  0.,   0.,   0.,   1., 994.,   5.,   0.,   0.,   0.,   0.],
#         [  0.,   0.,   0.,  57., 848.,  95.,   0.,   0.,   0.,   0.],
#         [  0.,   0.,   1., 146., 685., 166.,   2.,   0.,   0.,   0.],
#         [  0.,   0.,  12., 197., 522., 251.,  17.,   1.,   0.,   0.],
#         [  0.,   1.,  37., 222., 462., 235.,  42.,   1.,   0.,   0.],
#         [  1.,   6.,  58., 216., 398., 255.,  59.,   6.,   1.,   0.],
#         [  0.,  15.,  82., 232., 309., 253.,  90.,  18.,   1.,   0.],
#         [  4.,  27., 109., 225., 258., 221., 117.,  31.,   7.,   1.],
#         [ 13.,  34.,  97., 214., 263., 190., 118.,  53.,  15.,   3.]]),
#  array([ 73.43470005,  79.27121132,  85.10772259,  90.94423386,
#          96.78074513, 102.6172564 , 108.45376768, 114.29027895,
#         120.12679022, 125.96330149, 131.79981276]),
#  <a list of 9 BarContainer objects>)

# %%
data = np.random.normal(100,2,1000)
new_list=[]
new_list.extend(repeat(given_value,1000))
plt.pie(data)
plt.show()
# Out:
# 1000
